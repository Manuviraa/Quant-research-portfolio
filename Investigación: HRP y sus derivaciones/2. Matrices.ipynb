# %% [markdown]
# ## **Ejercicio 1: Operaciones sin bucles**
#
# Tienes un arreglo de NumPy que representa precios precios = np.array([100, 102, 105, 101]).
#
# Sin usar ningún bucle, suma 5 a todos los precios y luego multiplícalos por 2.

# %%
import numpy as np

# %%
arreglo = np.array([100,102,105,101])

# %%
(arreglo + 5) * 2
# Out:
# array([210, 214, 220, 212])

# %% [markdown]
# **Ejercicio 2: Retornos logarítmicos vectorizados**
#
# El problema: Toma el arreglo de precios del Ejercicio 1. Calcula los retornos logarítmicos continuos para esos precios.

# %%
log_returns = np.log(arreglo[1:] / arreglo[:-1])

# %%
log_returns
# Out:
# array([ 0.01980263,  0.02898754, -0.03883983])

# %%
arreglo[1:]
# Out:
# array([102, 105, 101])

# %%
arreglo[:-1]
# Out:
# array([100, 102, 105])
